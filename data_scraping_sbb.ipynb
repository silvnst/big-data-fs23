# %% [markdown]
# # Data Scraping

# %% [markdown]
# Dieses Jupyter Notebook wurde genutzt, um alle Verbindungen im Schweizer ÖV-Betriebsnetz zu scrapen und die Daten in einem Dataframe zu filtern und exportieren. Da die Dateien jeweils mehrere GB speicher benötigten, wurden die gescrapten Dateien direkt gelöscht und nur die relevanten Informationen gespeichert.

# %%
# import libraries
import os
import pandas as pd
import requests
import zipfile
import App.helper.config as config
import shutil

# %%
# Function to filter the data
def filter_data(data: pd.DataFrame, haltestellen: list, linien: str):
    # find number if NaN values in the HALTESTELLEN_NAME and LINIEN_TEXT columns
    print("Number of NaN values in HALTESTELLEN_NAME column: ", data['HALTESTELLEN_NAME'].isnull().sum())
    print("Number of NaN values in LINIEN_TEXT column: ", data['LINIEN_TEXT'].isnull().sum())
    # drop rows with NaN values in the HALTESTELLEN_NAME and LINIEN_TEXT columns
    data.dropna(subset=['HALTESTELLEN_NAME', 'LINIEN_TEXT'], inplace=True)
    # Filter HALTESTELLEN_NAME by the list of stations
    data = data[data['HALTESTELLEN_NAME'].isin(haltestellen)]
    # Filter LINIEN_TEXT by the list of lines
    data = data[data['LINIEN_TEXT'].str.contains(linien)]
    return data

# %%
def merge_stations(df, station_1, station_2):
    # Define columns variable
    columns = ['BETRIEBSTAG', 'LINIEN_ID', 'LINIEN_TEXT']

    # Filter df for station_1 and station_2
    df = df[(df['HALTESTELLEN_NAME'] == station_1) | (df['HALTESTELLEN_NAME'] == station_2)]

    # Create new dataframe with AN_soll, AN_ist, AN_diff if AN_ist_STATUS is "REAL"
    df_an = df[df['AN_ist_STATUS'] == 'REAL'][columns + ['HALTESTELLEN_NAME', 'AN_soll', 'AN_ist', 'AN_diff']]
    # Rename column HALTESTELLEN_NAME to haltestelle_an
    df_an = df_an.rename(columns={'HALTESTELLEN_NAME': 'haltestelle_an'})

    # Create new dataframe with AB_soll, AB_ist, AB_diff if AB_ist_STATUS is "REAL"
    df_ab = df[(df['AB_ist_STATUS'] == 'REAL')][columns + ['HALTESTELLEN_NAME', 'AB_soll', 'AB_ist', 'AB_diff']]
    # Rename column HALTESTELLEN_NAME to haltestelle_ab
    df_ab = df_ab.rename(columns={'HALTESTELLEN_NAME': 'haltestelle_ab'})

    # Merge dataframes df_an and df_ab by BETRIEBSTAG and LINIEN_ID
    df_merged = pd.merge(df_an, df_ab, on=columns)

    # Drop rows with haltestelle_an == haltestelle_ab
    df_merged = df_merged[df_merged['haltestelle_an'] != df_merged['haltestelle_ab']]

    return df_merged

# %%
# Funtion to convert data to correct format
def convert_data(df):

    # Rename columns, replace names ending with PROGNOSE with ist
    df.columns = df.columns.str.replace('PROGNOSE', 'ist')
    # Replace ANKUNFTSZEIT with AN_soll und ABFAHRTSZEIT with AB_soll
    df.columns = df.columns.str.replace('ANKUNFTSZEIT', 'AN_soll')
    df.columns = df.columns.str.replace('ABFAHRTSZEIT', 'AB_soll')

    # Create new column AN_diff with difference between AN_ist and AN_soll
    df['AN_diff'] = df['AN_ist'] - df['AN_soll']

    # Create new column AB_diff with difference between AB_ist and AB_soll
    df['AB_diff'] = df['AB_ist'] - df['AB_soll']

    # Find stations
    haltestellen = df['HALTESTELLEN_NAME'].unique()
    
    # Create empty dataframe to store merged data
    df_merged = pd.DataFrame()

    # Apply merge_stations function to all station combinations
    for station_1 in haltestellen:
        for station_2 in haltestellen:
            if station_1 != station_2:
                df_merged = pd.concat([df_merged, merge_stations(df, station_1, station_2)])
                    
    # Create new columns from BETRIEBSTAG: weekday
    df_merged['weekday'] = df_merged['BETRIEBSTAG'].dt.weekday

    # Create column ab_hour and ab_minute from AB_soll
    df_merged['ab_hour'] = df_merged['AB_soll'].dt.hour
    df_merged['ab_minute'] = df_merged['AB_soll'].dt.minute

    # Convert timedelta to minutes
    df_merged['AN_diff'] = df_merged['AN_diff'].dt.total_seconds() / 60
    df_merged['AB_diff'] = df_merged['AB_diff'].dt.total_seconds() / 60

    return df_merged

# %%
def process_data(url, data, item):

    # Define the folder to extract the zip file contents
    folder_name = 'Zipped_data'

    # Download the zip file
    r = requests.get(url)
    
    with open(f'ist-daten-{item}.zip', 'wb') as f:
        f.write(r.content)
    
    # Extract the contents of the zip file into the folder
    with zipfile.ZipFile(f'ist-daten-{item}.zip', 'r') as zip_ref:
        zip_ref.extractall(folder_name)
    
    # Read each file in the folder into a DataFrame and store them in a list
    haltestellen = config.HALTESTELLEN 
    # Linien types as string separated by |
    linien = '|'.join(config.LINIEN_TYPES)
    # Define empty list to store dataframes
    df_list = []
    print(f"Processing data...")
    # Loop through all files in the folder
    for file_name in os.listdir(folder_name):
        # Check if file is a csv file
        if file_name.endswith('.csv'):
            print(file_name)
            file_path = os.path.join(folder_name, file_name)
            print(file_path)
            # Read csv file into a DataFrame
            df = pd.read_csv(file_path, delimiter = ';', on_bad_lines='skip', parse_dates=['BETRIEBSTAG', 'ANKUNFTSZEIT', 'ABFAHRTSZEIT', 'AB_PROGNOSE', 'AN_PROGNOSE'], dayfirst=True, low_memory=False)
            # Filter data
            df = filter_data(df, haltestellen, linien)
            # Convert data
            df = convert_data(df)
            # Append DataFrame to list
            df_list.append(df)
            print(f"processed {file_name}.")

    # Concatenate the DataFrames into a single DataFrame
    df_combined = pd.concat(df_list, axis=0)
    
    # Delete the folder and the zip file
    osx_path = os.path.join(folder_name, '__MACOSX')
    if os.path.isdir(osx_path):
        shutil.rmtree(osx_path)
        print(f'Removed directory: {osx_path}')
    else:
        print(f'Directory not found: {osx_path}')
    os.remove(f'ist-daten-{item}.zip')
    
    # Delete all files in folder
    for file_name in os.listdir(folder_name):
        file_path = os.path.join(folder_name, file_name)
        if os.path.isdir(file_path):
            os.rmdir(file_path)
            print(f'if os.path.isdir(file_path):{file_path}')
        else:
            os.remove(file_path)
            print(f'else:{file_path}')
    # Delete folder
    if len(os.listdir(folder_name)) == 0:
        os.rmdir(folder_name)
        print(f'len(os.listdir(folder_name)) == 0{folder_name}')
    else:
        print(f"Unable to delete directory {folder_name} as it still contains files.")
    return df_combined

# %%
def process_special_data(url, data, item):

    # Define the folder to extract the zip file contents
    folder_name = 'Zipped_data'
    
    # Download the zip file
    r = requests.get(url)
    
    with open(f'ist-daten-{item}.zip', 'wb') as f:
        f.write(r.content)
    
    # Extract the contents of the zip file into the folder
    with zipfile.ZipFile(f'ist-daten-{item}.zip', 'r') as zip_ref:
        zip_ref.extractall(folder_name)
    
    # Read each file in the folder into a DataFrame and store them in a list
    haltestellen = config.HALTESTELLEN 
    # Linien types as string separated by |
    linien = '|'.join(config.LINIEN_TYPES)

    # Define empty list to store dataframes
    df_list = []
    print(f"Processing data...")
    # Loop through all files in the folder
    for file_name in os.listdir(f'{folder_name}/ist-daten-{item}'):
        # Check if file is a csv file
        if file_name.endswith('.csv'):
            print(file_name)
            file_path = os.path.join(f'{folder_name}/ist-daten-{item}', file_name)
            print(file_path)
            # Read csv file into a DataFrame
            df = pd.read_csv(file_path, delimiter = ';', on_bad_lines='skip', parse_dates=['BETRIEBSTAG', 'ANKUNFTSZEIT', 'ABFAHRTSZEIT', 'AB_PROGNOSE', 'AN_PROGNOSE'], dayfirst=True, low_memory=False)
            # Filter data
            df = filter_data(df, haltestellen, linien)
            # Convert data
            df = convert_data(df)
            # Append DataFrame to list
            df_list.append(df)
            print(f"processed {file_name}.")

    # Concatenate the DataFrames into a single DataFrame
    df_combined = pd.concat(df_list, axis=0)
   
    # Delete the folder and the zip file
    os.remove(f'ist-daten-{item}.zip')
    #Delete manually
    return df_combined

# %% [markdown]
# Die erarbeitenen Funtionen werden in diesem Teil ausgeführt.

# %%
# Define the folder to extract the zip file contents
scraper_list = ['2023-05', '2023-03', '2023-02', '2023-01','2022-11', '2022-10', '2022-09', '2022-08', '2022-07', '2022-06']
scraper_list += ['2022-05', '2022-04', '2022-03', '2022-02', '2022-01', '2021-12', '2021-11', '2021-10', '2021-09', '2021-08', '2021-07', '2021-06']
# Define empty DataFrame to store the combined data
data = pd.DataFrame()
for item in scraper_list:
    url = f'https://opentransportdata.swiss/wp-content/uploads/ist-daten-archive/ist-daten-{item}.zip'
    data = process_data(url, data, item)
    data.to_csv(f'Daten/v3/combined_data_{item}.csv', index=False)
# Out:
# Processing data...
# 2023-03-01_istdaten.csv
# Zipped_data\2023-03-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162842
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-01_istdaten.csv.
# 2023-03-02_istdaten.csv
# Zipped_data\2023-03-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163527
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-02_istdaten.csv.
# 2023-03-03_istdaten.csv
# Zipped_data\2023-03-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164654
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-03_istdaten.csv.
# 2023-03-04_istdaten.csv
# Zipped_data\2023-03-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135707
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-04_istdaten.csv.
# 2023-03-05_istdaten.csv
# Zipped_data\2023-03-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97656
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-05_istdaten.csv.
# 2023-03-06_istdaten.csv
# Zipped_data\2023-03-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  155606
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-06_istdaten.csv.
# 2023-03-07_istdaten.csv
# Zipped_data\2023-03-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163210
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-07_istdaten.csv.
# 2023-03-08_istdaten.csv
# Zipped_data\2023-03-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  131015
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2023-03-08_istdaten.csv.
# 2023-03-09_istdaten.csv
# Zipped_data\2023-03-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159808
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-09_istdaten.csv.
# 2023-03-10_istdaten.csv
# Zipped_data\2023-03-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158734
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-10_istdaten.csv.
# 2023-03-11_istdaten.csv
# Zipped_data\2023-03-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135252
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-11_istdaten.csv.
# 2023-03-12_istdaten.csv
# Zipped_data\2023-03-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97013
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-12_istdaten.csv.
# 2023-03-13_istdaten.csv
# Zipped_data\2023-03-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162699
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-13_istdaten.csv.
# 2023-03-14_istdaten.csv
# Zipped_data\2023-03-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163137
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-14_istdaten.csv.
# 2023-03-15_istdaten.csv
# Zipped_data\2023-03-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161865
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-15_istdaten.csv.
# 2023-03-16_istdaten.csv
# Zipped_data\2023-03-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164128
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-16_istdaten.csv.
# 2023-03-17_istdaten.csv
# Zipped_data\2023-03-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164825
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-17_istdaten.csv.
# 2023-03-18_istdaten.csv
# Zipped_data\2023-03-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135584
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-18_istdaten.csv.
# 2023-03-19_istdaten.csv
# Zipped_data\2023-03-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97368
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-19_istdaten.csv.
# 2023-03-20_istdaten.csv
# Zipped_data\2023-03-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163500
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-20_istdaten.csv.
# 2023-03-21_istdaten.csv
# Zipped_data\2023-03-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163090
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-21_istdaten.csv.
# 2023-03-22_istdaten.csv
# Zipped_data\2023-03-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163066
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2023-03-22_istdaten.csv.
# 2023-03-23_istdaten.csv
# Zipped_data\2023-03-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163524
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-23_istdaten.csv.
# 2023-03-24_istdaten.csv
# Zipped_data\2023-03-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164971
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-24_istdaten.csv.
# 2023-03-25_istdaten.csv
# Zipped_data\2023-03-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  118230
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-25_istdaten.csv.
# 2023-03-26_istdaten.csv
# Zipped_data\2023-03-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  96829
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-26_istdaten.csv.
# 2023-03-27_istdaten.csv
# Zipped_data\2023-03-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160143
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-27_istdaten.csv.
# 2023-03-28_istdaten.csv
# Zipped_data\2023-03-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162102
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-28_istdaten.csv.
# 2023-03-29_istdaten.csv
# Zipped_data\2023-03-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161997
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-29_istdaten.csv.
# 2023-03-30_istdaten.csv
# Zipped_data\2023-03-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162736
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-30_istdaten.csv.
# 2023-03-31_istdaten.csv
# Zipped_data\2023-03-31_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  145799
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-03-31_istdaten.csv.
# Removed directory: Zipped_data\__MACOSX
# else:Zipped_data\2023-03-01_istdaten.csv
# else:Zipped_data\2023-03-02_istdaten.csv
# else:Zipped_data\2023-03-03_istdaten.csv
# else:Zipped_data\2023-03-04_istdaten.csv
# else:Zipped_data\2023-03-05_istdaten.csv
# else:Zipped_data\2023-03-06_istdaten.csv
# else:Zipped_data\2023-03-07_istdaten.csv
# else:Zipped_data\2023-03-08_istdaten.csv
# else:Zipped_data\2023-03-09_istdaten.csv
# else:Zipped_data\2023-03-10_istdaten.csv
# else:Zipped_data\2023-03-11_istdaten.csv
# else:Zipped_data\2023-03-12_istdaten.csv
# else:Zipped_data\2023-03-13_istdaten.csv
# else:Zipped_data\2023-03-14_istdaten.csv
# else:Zipped_data\2023-03-15_istdaten.csv
# else:Zipped_data\2023-03-16_istdaten.csv
# else:Zipped_data\2023-03-17_istdaten.csv
# else:Zipped_data\2023-03-18_istdaten.csv
# else:Zipped_data\2023-03-19_istdaten.csv
# else:Zipped_data\2023-03-20_istdaten.csv
# else:Zipped_data\2023-03-21_istdaten.csv
# else:Zipped_data\2023-03-22_istdaten.csv
# else:Zipped_data\2023-03-23_istdaten.csv
# else:Zipped_data\2023-03-24_istdaten.csv
# else:Zipped_data\2023-03-25_istdaten.csv
# else:Zipped_data\2023-03-26_istdaten.csv
# else:Zipped_data\2023-03-27_istdaten.csv
# else:Zipped_data\2023-03-28_istdaten.csv
# else:Zipped_data\2023-03-29_istdaten.csv
# else:Zipped_data\2023-03-30_istdaten.csv
# else:Zipped_data\2023-03-31_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2023-02-01_istdaten.csv
# Zipped_data\2023-02-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163183
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-01_istdaten.csv.
# 2023-02-02_istdaten.csv
# Zipped_data\2023-02-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163430
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2023-02-02_istdaten.csv.
# 2023-02-03_istdaten.csv
# Zipped_data\2023-02-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164801
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-03_istdaten.csv.
# 2023-02-04_istdaten.csv
# Zipped_data\2023-02-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135946
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-04_istdaten.csv.
# 2023-02-05_istdaten.csv
# Zipped_data\2023-02-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97581
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-05_istdaten.csv.
# 2023-02-06_istdaten.csv
# Zipped_data\2023-02-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162930
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-06_istdaten.csv.
# 2023-02-07_istdaten.csv
# Zipped_data\2023-02-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161571
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-07_istdaten.csv.
# 2023-02-08_istdaten.csv
# Zipped_data\2023-02-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163066
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-08_istdaten.csv.
# 2023-02-09_istdaten.csv
# Zipped_data\2023-02-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163084
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-09_istdaten.csv.
# 2023-02-10_istdaten.csv
# Zipped_data\2023-02-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164342
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-10_istdaten.csv.
# 2023-02-11_istdaten.csv
# Zipped_data\2023-02-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  134895
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-11_istdaten.csv.
# 2023-02-12_istdaten.csv
# Zipped_data\2023-02-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97543
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-12_istdaten.csv.
# 2023-02-13_istdaten.csv
# Zipped_data\2023-02-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162463
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2023-02-13_istdaten.csv.
# 2023-02-14_istdaten.csv
# Zipped_data\2023-02-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158196
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-14_istdaten.csv.
# 2023-02-15_istdaten.csv
# Zipped_data\2023-02-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162242
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-15_istdaten.csv.
# 2023-02-16_istdaten.csv
# Zipped_data\2023-02-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161511
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-16_istdaten.csv.
# 2023-02-17_istdaten.csv
# Zipped_data\2023-02-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163426
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-17_istdaten.csv.
# 2023-02-18_istdaten.csv
# Zipped_data\2023-02-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135368
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-18_istdaten.csv.
# 2023-02-19_istdaten.csv
# Zipped_data\2023-02-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97592
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-19_istdaten.csv.
# 2023-02-20_istdaten.csv
# Zipped_data\2023-02-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161872
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-20_istdaten.csv.
# 2023-02-21_istdaten.csv
# Zipped_data\2023-02-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161920
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-21_istdaten.csv.
# 2023-02-22_istdaten.csv
# Zipped_data\2023-02-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162156
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-22_istdaten.csv.
# 2023-02-23_istdaten.csv
# Zipped_data\2023-02-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163128
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-23_istdaten.csv.
# 2023-02-24_istdaten.csv
# Zipped_data\2023-02-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159575
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-24_istdaten.csv.
# 2023-02-25_istdaten.csv
# Zipped_data\2023-02-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  127853
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-25_istdaten.csv.
# 2023-02-26_istdaten.csv
# Zipped_data\2023-02-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  91561
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-26_istdaten.csv.
# 2023-02-27_istdaten.csv
# Zipped_data\2023-02-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163093
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-27_istdaten.csv.
# 2023-02-28_istdaten.csv
# Zipped_data\2023-02-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163227
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-02-28_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2023-02-01_istdaten.csv
# else:Zipped_data\2023-02-02_istdaten.csv
# else:Zipped_data\2023-02-03_istdaten.csv
# else:Zipped_data\2023-02-04_istdaten.csv
# else:Zipped_data\2023-02-05_istdaten.csv
# else:Zipped_data\2023-02-06_istdaten.csv
# else:Zipped_data\2023-02-07_istdaten.csv
# else:Zipped_data\2023-02-08_istdaten.csv
# else:Zipped_data\2023-02-09_istdaten.csv
# else:Zipped_data\2023-02-10_istdaten.csv
# else:Zipped_data\2023-02-11_istdaten.csv
# else:Zipped_data\2023-02-12_istdaten.csv
# else:Zipped_data\2023-02-13_istdaten.csv
# else:Zipped_data\2023-02-14_istdaten.csv
# else:Zipped_data\2023-02-15_istdaten.csv
# else:Zipped_data\2023-02-16_istdaten.csv
# else:Zipped_data\2023-02-17_istdaten.csv
# else:Zipped_data\2023-02-18_istdaten.csv
# else:Zipped_data\2023-02-19_istdaten.csv
# else:Zipped_data\2023-02-20_istdaten.csv
# else:Zipped_data\2023-02-21_istdaten.csv
# else:Zipped_data\2023-02-22_istdaten.csv
# else:Zipped_data\2023-02-23_istdaten.csv
# else:Zipped_data\2023-02-24_istdaten.csv
# else:Zipped_data\2023-02-25_istdaten.csv
# else:Zipped_data\2023-02-26_istdaten.csv
# else:Zipped_data\2023-02-27_istdaten.csv
# else:Zipped_data\2023-02-28_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2023-01-01_istdaten.csv
# Zipped_data\2023-01-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  92934
# Number of NaN values in LINIEN_TEXT column:  34
# processed 2023-01-01_istdaten.csv.
# 2023-01-02_istdaten.csv
# Zipped_data\2023-01-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  123496
# Number of NaN values in LINIEN_TEXT column:  34
# processed 2023-01-02_istdaten.csv.
# 2023-01-03_istdaten.csv
# Zipped_data\2023-01-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  155757
# Number of NaN values in LINIEN_TEXT column:  34
# processed 2023-01-03_istdaten.csv.
# 2023-01-04_istdaten.csv
# Zipped_data\2023-01-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158996
# Number of NaN values in LINIEN_TEXT column:  34
# processed 2023-01-04_istdaten.csv.
# 2023-01-05_istdaten.csv
# Zipped_data\2023-01-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160911
# Number of NaN values in LINIEN_TEXT column:  34
# processed 2023-01-05_istdaten.csv.
# 2023-01-06_istdaten.csv
# Zipped_data\2023-01-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161658
# Number of NaN values in LINIEN_TEXT column:  34
# processed 2023-01-06_istdaten.csv.
# 2023-01-07_istdaten.csv
# Zipped_data\2023-01-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  130886
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-07_istdaten.csv.
# 2023-01-08_istdaten.csv
# Zipped_data\2023-01-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97285
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-08_istdaten.csv.
# 2023-01-09_istdaten.csv
# Zipped_data\2023-01-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162433
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-09_istdaten.csv.
# 2023-01-10_istdaten.csv
# Zipped_data\2023-01-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163252
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-10_istdaten.csv.
# 2023-01-11_istdaten.csv
# Zipped_data\2023-01-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162550
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-11_istdaten.csv.
# 2023-01-12_istdaten.csv
# Zipped_data\2023-01-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163859
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-12_istdaten.csv.
# 2023-01-13_istdaten.csv
# Zipped_data\2023-01-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164694
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-13_istdaten.csv.
# 2023-01-14_istdaten.csv
# Zipped_data\2023-01-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  136009
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-14_istdaten.csv.
# 2023-01-15_istdaten.csv
# Zipped_data\2023-01-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97693
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-15_istdaten.csv.
# 2023-01-16_istdaten.csv
# Zipped_data\2023-01-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158625
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-16_istdaten.csv.
# 2023-01-17_istdaten.csv
# Zipped_data\2023-01-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158526
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-17_istdaten.csv.
# 2023-01-18_istdaten.csv
# Zipped_data\2023-01-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  157830
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-18_istdaten.csv.
# 2023-01-19_istdaten.csv
# Zipped_data\2023-01-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158826
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-19_istdaten.csv.
# 2023-01-20_istdaten.csv
# Zipped_data\2023-01-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159746
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-20_istdaten.csv.
# 2023-01-21_istdaten.csv
# Zipped_data\2023-01-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135516
# Number of NaN values in LINIEN_TEXT column:  3
# processed 2023-01-21_istdaten.csv.
# 2023-01-22_istdaten.csv
# Zipped_data\2023-01-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97717
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-22_istdaten.csv.
# 2023-01-23_istdaten.csv
# Zipped_data\2023-01-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163014
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-23_istdaten.csv.
# 2023-01-24_istdaten.csv
# Zipped_data\2023-01-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163660
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-24_istdaten.csv.
# 2023-01-25_istdaten.csv
# Zipped_data\2023-01-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162967
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-25_istdaten.csv.
# 2023-01-26_istdaten.csv
# Zipped_data\2023-01-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163621
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-26_istdaten.csv.
# 2023-01-27_istdaten.csv
# Zipped_data\2023-01-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164617
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-27_istdaten.csv.
# 2023-01-28_istdaten.csv
# Zipped_data\2023-01-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135484
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-28_istdaten.csv.
# 2023-01-29_istdaten.csv
# Zipped_data\2023-01-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97830
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-29_istdaten.csv.
# 2023-01-30_istdaten.csv
# Zipped_data\2023-01-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163398
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-30_istdaten.csv.
# 2023-01-31_istdaten.csv
# Zipped_data\2023-01-31_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163378
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-01-31_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2023-01-01_istdaten.csv
# else:Zipped_data\2023-01-02_istdaten.csv
# else:Zipped_data\2023-01-03_istdaten.csv
# else:Zipped_data\2023-01-04_istdaten.csv
# else:Zipped_data\2023-01-05_istdaten.csv
# else:Zipped_data\2023-01-06_istdaten.csv
# else:Zipped_data\2023-01-07_istdaten.csv
# else:Zipped_data\2023-01-08_istdaten.csv
# else:Zipped_data\2023-01-09_istdaten.csv
# else:Zipped_data\2023-01-10_istdaten.csv
# else:Zipped_data\2023-01-11_istdaten.csv
# else:Zipped_data\2023-01-12_istdaten.csv
# else:Zipped_data\2023-01-13_istdaten.csv
# else:Zipped_data\2023-01-14_istdaten.csv
# else:Zipped_data\2023-01-15_istdaten.csv
# else:Zipped_data\2023-01-16_istdaten.csv
# else:Zipped_data\2023-01-17_istdaten.csv
# else:Zipped_data\2023-01-18_istdaten.csv
# else:Zipped_data\2023-01-19_istdaten.csv
# else:Zipped_data\2023-01-20_istdaten.csv
# else:Zipped_data\2023-01-21_istdaten.csv
# else:Zipped_data\2023-01-22_istdaten.csv
# else:Zipped_data\2023-01-23_istdaten.csv
# else:Zipped_data\2023-01-24_istdaten.csv
# else:Zipped_data\2023-01-25_istdaten.csv
# else:Zipped_data\2023-01-26_istdaten.csv
# else:Zipped_data\2023-01-27_istdaten.csv
# else:Zipped_data\2023-01-28_istdaten.csv
# else:Zipped_data\2023-01-29_istdaten.csv
# else:Zipped_data\2023-01-30_istdaten.csv
# else:Zipped_data\2023-01-31_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2022-11-01_istdaten.csv
# Zipped_data\2022-11-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  138974
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-01_istdaten.csv.
# 2022-11-02_istdaten.csv
# Zipped_data\2022-11-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163151
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-02_istdaten.csv.
# 2022-11-03_istdaten.csv
# Zipped_data\2022-11-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164447
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-03_istdaten.csv.
# 2022-11-04_istdaten.csv
# Zipped_data\2022-11-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159205
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-04_istdaten.csv.
# 2022-11-05_istdaten.csv
# Zipped_data\2022-11-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  136051
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-11-05_istdaten.csv.
# 2022-11-06_istdaten.csv
# Zipped_data\2022-11-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  95172
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-06_istdaten.csv.
# 2022-11-07_istdaten.csv
# Zipped_data\2022-11-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164337
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-07_istdaten.csv.
# 2022-11-08_istdaten.csv
# Zipped_data\2022-11-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  59895
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-08_istdaten.csv.
# 2022-11-09_istdaten.csv
# Zipped_data\2022-11-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  0
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-09_istdaten.csv.
# 2022-11-10_istdaten.csv
# Zipped_data\2022-11-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  107392
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-10_istdaten.csv.
# 2022-11-11_istdaten.csv
# Zipped_data\2022-11-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163376
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-11_istdaten.csv.
# 2022-11-12_istdaten.csv
# Zipped_data\2022-11-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  134751
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-12_istdaten.csv.
# 2022-11-13_istdaten.csv
# Zipped_data\2022-11-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  94232
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-13_istdaten.csv.
# 2022-11-14_istdaten.csv
# Zipped_data\2022-11-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158233
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-11-14_istdaten.csv.
# 2022-11-15_istdaten.csv
# Zipped_data\2022-11-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159699
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-11-15_istdaten.csv.
# 2022-11-16_istdaten.csv
# Zipped_data\2022-11-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160898
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-16_istdaten.csv.
# 2022-11-17_istdaten.csv
# Zipped_data\2022-11-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161870
# Number of NaN values in LINIEN_TEXT column:  4
# processed 2022-11-17_istdaten.csv.
# 2022-11-18_istdaten.csv
# Zipped_data\2022-11-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  156646
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-18_istdaten.csv.
# 2022-11-19_istdaten.csv
# Zipped_data\2022-11-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  134309
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-19_istdaten.csv.
# 2022-11-20_istdaten.csv
# Zipped_data\2022-11-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  94255
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-20_istdaten.csv.
# 2022-11-21_istdaten.csv
# Zipped_data\2022-11-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160554
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-21_istdaten.csv.
# 2022-11-22_istdaten.csv
# Zipped_data\2022-11-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159073
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-22_istdaten.csv.
# 2022-11-23_istdaten.csv
# Zipped_data\2022-11-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  150244
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-23_istdaten.csv.
# 2022-11-24_istdaten.csv
# Zipped_data\2022-11-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161104
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-24_istdaten.csv.
# 2022-11-25_istdaten.csv
# Zipped_data\2022-11-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162882
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-25_istdaten.csv.
# 2022-11-26_istdaten.csv
# Zipped_data\2022-11-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  134417
# Number of NaN values in LINIEN_TEXT column:  18
# processed 2022-11-26_istdaten.csv.
# 2022-11-27_istdaten.csv
# Zipped_data\2022-11-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  92591
# Number of NaN values in LINIEN_TEXT column:  22
# processed 2022-11-27_istdaten.csv.
# 2022-11-28_istdaten.csv
# Zipped_data\2022-11-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  157489
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-28_istdaten.csv.
# 2022-11-29_istdaten.csv
# Zipped_data\2022-11-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160447
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-11-29_istdaten.csv.
# 2022-11-30_istdaten.csv
# Zipped_data\2022-11-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160742
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-11-30_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2022-11-01_istdaten.csv
# else:Zipped_data\2022-11-02_istdaten.csv
# else:Zipped_data\2022-11-03_istdaten.csv
# else:Zipped_data\2022-11-04_istdaten.csv
# else:Zipped_data\2022-11-05_istdaten.csv
# else:Zipped_data\2022-11-06_istdaten.csv
# else:Zipped_data\2022-11-07_istdaten.csv
# else:Zipped_data\2022-11-08_istdaten.csv
# else:Zipped_data\2022-11-09_istdaten.csv
# else:Zipped_data\2022-11-10_istdaten.csv
# else:Zipped_data\2022-11-11_istdaten.csv
# else:Zipped_data\2022-11-12_istdaten.csv
# else:Zipped_data\2022-11-13_istdaten.csv
# else:Zipped_data\2022-11-14_istdaten.csv
# else:Zipped_data\2022-11-15_istdaten.csv
# else:Zipped_data\2022-11-16_istdaten.csv
# else:Zipped_data\2022-11-17_istdaten.csv
# else:Zipped_data\2022-11-18_istdaten.csv
# else:Zipped_data\2022-11-19_istdaten.csv
# else:Zipped_data\2022-11-20_istdaten.csv
# else:Zipped_data\2022-11-21_istdaten.csv
# else:Zipped_data\2022-11-22_istdaten.csv
# else:Zipped_data\2022-11-23_istdaten.csv
# else:Zipped_data\2022-11-24_istdaten.csv
# else:Zipped_data\2022-11-25_istdaten.csv
# else:Zipped_data\2022-11-26_istdaten.csv
# else:Zipped_data\2022-11-27_istdaten.csv
# else:Zipped_data\2022-11-28_istdaten.csv
# else:Zipped_data\2022-11-29_istdaten.csv
# else:Zipped_data\2022-11-30_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2022-10-01_istdaten.csv
# Zipped_data\2022-10-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  138275
# Number of NaN values in LINIEN_TEXT column:  84
# processed 2022-10-01_istdaten.csv.
# 2022-10-02_istdaten.csv
# Zipped_data\2022-10-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  96279
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2022-10-02_istdaten.csv.
# 2022-10-03_istdaten.csv
# Zipped_data\2022-10-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163695
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-10-03_istdaten.csv.
# 2022-10-04_istdaten.csv
# Zipped_data\2022-10-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164447
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-10-04_istdaten.csv.
# 2022-10-05_istdaten.csv
# Zipped_data\2022-10-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  150720
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-05_istdaten.csv.
# 2022-10-06_istdaten.csv
# Zipped_data\2022-10-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159909
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-06_istdaten.csv.
# 2022-10-07_istdaten.csv
# Zipped_data\2022-10-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166200
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-10-07_istdaten.csv.
# 2022-10-08_istdaten.csv
# Zipped_data\2022-10-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  139332
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-08_istdaten.csv.
# 2022-10-09_istdaten.csv
# Zipped_data\2022-10-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97776
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-09_istdaten.csv.
# 2022-10-10_istdaten.csv
# Zipped_data\2022-10-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164445
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-10_istdaten.csv.
# 2022-10-11_istdaten.csv
# Zipped_data\2022-10-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165018
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-11_istdaten.csv.
# 2022-10-12_istdaten.csv
# Zipped_data\2022-10-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165146
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-12_istdaten.csv.
# 2022-10-13_istdaten.csv
# Zipped_data\2022-10-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166381
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-13_istdaten.csv.
# 2022-10-14_istdaten.csv
# Zipped_data\2022-10-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166592
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-14_istdaten.csv.
# 2022-10-15_istdaten.csv
# Zipped_data\2022-10-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  140089
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2022-10-15_istdaten.csv.
# 2022-10-16_istdaten.csv
# Zipped_data\2022-10-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  99074
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-16_istdaten.csv.
# 2022-10-17_istdaten.csv
# Zipped_data\2022-10-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  154103
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-17_istdaten.csv.
# 2022-10-18_istdaten.csv
# Zipped_data\2022-10-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166516
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-18_istdaten.csv.
# 2022-10-19_istdaten.csv
# Zipped_data\2022-10-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165798
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-19_istdaten.csv.
# 2022-10-20_istdaten.csv
# Zipped_data\2022-10-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164341
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-10-20_istdaten.csv.
# 2022-10-21_istdaten.csv
# Zipped_data\2022-10-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164711
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-21_istdaten.csv.
# 2022-10-22_istdaten.csv
# Zipped_data\2022-10-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  138679
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-22_istdaten.csv.
# 2022-10-23_istdaten.csv
# Zipped_data\2022-10-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  98010
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-23_istdaten.csv.
# 2022-10-24_istdaten.csv
# Zipped_data\2022-10-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164867
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-24_istdaten.csv.
# 2022-10-25_istdaten.csv
# Zipped_data\2022-10-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163991
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-25_istdaten.csv.
# 2022-10-26_istdaten.csv
# Zipped_data\2022-10-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164525
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-26_istdaten.csv.
# 2022-10-27_istdaten.csv
# Zipped_data\2022-10-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165130
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-27_istdaten.csv.
# 2022-10-28_istdaten.csv
# Zipped_data\2022-10-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166228
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-28_istdaten.csv.
# 2022-10-29_istdaten.csv
# Zipped_data\2022-10-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  137330
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-29_istdaten.csv.
# 2022-10-30_istdaten.csv
# Zipped_data\2022-10-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  93992
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-30_istdaten.csv.
# 2022-10-31_istdaten.csv
# Zipped_data\2022-10-31_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165169
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-10-31_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2022-10-01_istdaten.csv
# else:Zipped_data\2022-10-02_istdaten.csv
# else:Zipped_data\2022-10-03_istdaten.csv
# else:Zipped_data\2022-10-04_istdaten.csv
# else:Zipped_data\2022-10-05_istdaten.csv
# else:Zipped_data\2022-10-06_istdaten.csv
# else:Zipped_data\2022-10-07_istdaten.csv
# else:Zipped_data\2022-10-08_istdaten.csv
# else:Zipped_data\2022-10-09_istdaten.csv
# else:Zipped_data\2022-10-10_istdaten.csv
# else:Zipped_data\2022-10-11_istdaten.csv
# else:Zipped_data\2022-10-12_istdaten.csv
# else:Zipped_data\2022-10-13_istdaten.csv
# else:Zipped_data\2022-10-14_istdaten.csv
# else:Zipped_data\2022-10-15_istdaten.csv
# else:Zipped_data\2022-10-16_istdaten.csv
# else:Zipped_data\2022-10-17_istdaten.csv
# else:Zipped_data\2022-10-18_istdaten.csv
# else:Zipped_data\2022-10-19_istdaten.csv
# else:Zipped_data\2022-10-20_istdaten.csv
# else:Zipped_data\2022-10-21_istdaten.csv
# else:Zipped_data\2022-10-22_istdaten.csv
# else:Zipped_data\2022-10-23_istdaten.csv
# else:Zipped_data\2022-10-24_istdaten.csv
# else:Zipped_data\2022-10-25_istdaten.csv
# else:Zipped_data\2022-10-26_istdaten.csv
# else:Zipped_data\2022-10-27_istdaten.csv
# else:Zipped_data\2022-10-28_istdaten.csv
# else:Zipped_data\2022-10-29_istdaten.csv
# else:Zipped_data\2022-10-30_istdaten.csv
# else:Zipped_data\2022-10-31_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2022-09-01_istdaten.csv
# Zipped_data\2022-09-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165597
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-01_istdaten.csv.
# 2022-09-02_istdaten.csv
# Zipped_data\2022-09-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166918
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-02_istdaten.csv.
# 2022-09-03_istdaten.csv
# Zipped_data\2022-09-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  134438
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-03_istdaten.csv.
# 2022-09-05_istdaten.csv
# Zipped_data\2022-09-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166067
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-05_istdaten.csv.
# 2022-09-06_istdaten.csv
# Zipped_data\2022-09-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165446
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-06_istdaten.csv.
# 2022-09-07_istdaten.csv
# Zipped_data\2022-09-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161067
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-07_istdaten.csv.
# 2022-09-08_istdaten.csv
# Zipped_data\2022-09-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166430
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-08_istdaten.csv.
# 2022-09-09_istdaten.csv
# Zipped_data\2022-09-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  163679
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-09-09_istdaten.csv.
# 2022-09-10_istdaten.csv
# Zipped_data\2022-09-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  138736
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-10_istdaten.csv.
# 2022-09-11_istdaten.csv
# Zipped_data\2022-09-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  70570
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-11_istdaten.csv.
# 2022-09-12_istdaten.csv
# Zipped_data\2022-09-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165547
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-12_istdaten.csv.
# 2022-09-13_istdaten.csv
# Zipped_data\2022-09-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165272
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-13_istdaten.csv.
# 2022-09-14_istdaten.csv
# Zipped_data\2022-09-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164918
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-09-14_istdaten.csv.
# 2022-09-15_istdaten.csv
# Zipped_data\2022-09-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161416
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2022-09-15_istdaten.csv.
# 2022-09-16_istdaten.csv
# Zipped_data\2022-09-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166467
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-16_istdaten.csv.
# 2022-09-17_istdaten.csv
# Zipped_data\2022-09-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  138855
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-17_istdaten.csv.
# 2022-09-18_istdaten.csv
# Zipped_data\2022-09-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  96644
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-18_istdaten.csv.
# 2022-09-19_istdaten.csv
# Zipped_data\2022-09-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  164720
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-19_istdaten.csv.
# 2022-09-20_istdaten.csv
# Zipped_data\2022-09-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  150893
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-20_istdaten.csv.
# 2022-09-21_istdaten.csv
# Zipped_data\2022-09-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  150681
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2022-09-21_istdaten.csv.
# 2022-09-22_istdaten.csv
# Zipped_data\2022-09-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  146907
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-22_istdaten.csv.
# 2022-09-23_istdaten.csv
# Zipped_data\2022-09-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  151476
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-23_istdaten.csv.
# 2022-09-24_istdaten.csv
# Zipped_data\2022-09-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  126952
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-24_istdaten.csv.
# 2022-09-25_istdaten.csv
# Zipped_data\2022-09-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  90234
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-25_istdaten.csv.
# 2022-09-26_istdaten.csv
# Zipped_data\2022-09-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  150594
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-26_istdaten.csv.
# 2022-09-27_istdaten.csv
# Zipped_data\2022-09-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  145014
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-27_istdaten.csv.
# 2022-09-28_istdaten.csv
# Zipped_data\2022-09-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158456
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-09-28_istdaten.csv.
# 2022-09-29_istdaten.csv
# Zipped_data\2022-09-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165688
# Number of NaN values in LINIEN_TEXT column:  4
# processed 2022-09-29_istdaten.csv.
# 2022-09-30_istdaten.csv
# Zipped_data\2022-09-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166542
# Number of NaN values in LINIEN_TEXT column:  84
# processed 2022-09-30_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2022-09-01_istdaten.csv
# else:Zipped_data\2022-09-02_istdaten.csv
# else:Zipped_data\2022-09-03_istdaten.csv
# else:Zipped_data\2022-09-05_istdaten.csv
# else:Zipped_data\2022-09-06_istdaten.csv
# else:Zipped_data\2022-09-07_istdaten.csv
# else:Zipped_data\2022-09-08_istdaten.csv
# else:Zipped_data\2022-09-09_istdaten.csv
# else:Zipped_data\2022-09-10_istdaten.csv
# else:Zipped_data\2022-09-11_istdaten.csv
# else:Zipped_data\2022-09-12_istdaten.csv
# else:Zipped_data\2022-09-13_istdaten.csv
# else:Zipped_data\2022-09-14_istdaten.csv
# else:Zipped_data\2022-09-15_istdaten.csv
# else:Zipped_data\2022-09-16_istdaten.csv
# else:Zipped_data\2022-09-17_istdaten.csv
# else:Zipped_data\2022-09-18_istdaten.csv
# else:Zipped_data\2022-09-19_istdaten.csv
# else:Zipped_data\2022-09-20_istdaten.csv
# else:Zipped_data\2022-09-21_istdaten.csv
# else:Zipped_data\2022-09-22_istdaten.csv
# else:Zipped_data\2022-09-23_istdaten.csv
# else:Zipped_data\2022-09-24_istdaten.csv
# else:Zipped_data\2022-09-25_istdaten.csv
# else:Zipped_data\2022-09-26_istdaten.csv
# else:Zipped_data\2022-09-27_istdaten.csv
# else:Zipped_data\2022-09-28_istdaten.csv
# else:Zipped_data\2022-09-29_istdaten.csv
# else:Zipped_data\2022-09-30_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2022-08-01_istdaten.csv
# Zipped_data\2022-08-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  70722
# Number of NaN values in LINIEN_TEXT column:  19
# processed 2022-08-01_istdaten.csv.
# 2022-08-02_istdaten.csv
# Zipped_data\2022-08-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159892
# Number of NaN values in LINIEN_TEXT column:  19
# processed 2022-08-02_istdaten.csv.
# 2022-08-03_istdaten.csv
# Zipped_data\2022-08-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159828
# Number of NaN values in LINIEN_TEXT column:  19
# processed 2022-08-03_istdaten.csv.
# 2022-08-04_istdaten.csv
# Zipped_data\2022-08-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160636
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2022-08-04_istdaten.csv.
# 2022-08-05_istdaten.csv
# Zipped_data\2022-08-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  162207
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-05_istdaten.csv.
# 2022-08-06_istdaten.csv
# Zipped_data\2022-08-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  139949
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-06_istdaten.csv.
# 2022-08-07_istdaten.csv
# Zipped_data\2022-08-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  98446
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-07_istdaten.csv.
# 2022-08-09_istdaten.csv
# Zipped_data\2022-08-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160381
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-09_istdaten.csv.
# 2022-08-10_istdaten.csv
# Zipped_data\2022-08-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160138
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-10_istdaten.csv.
# 2022-08-11_istdaten.csv
# Zipped_data\2022-08-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  154750
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-11_istdaten.csv.
# 2022-08-12_istdaten.csv
# Zipped_data\2022-08-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161776
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-12_istdaten.csv.
# 2022-08-13_istdaten.csv
# Zipped_data\2022-08-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  135161
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-13_istdaten.csv.
# 2022-08-14_istdaten.csv
# Zipped_data\2022-08-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97403
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-14_istdaten.csv.
# 2022-08-15_istdaten.csv
# Zipped_data\2022-08-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  156731
# Number of NaN values in LINIEN_TEXT column:  3
# processed 2022-08-15_istdaten.csv.
# 2022-08-16_istdaten.csv
# Zipped_data\2022-08-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  165705
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-16_istdaten.csv.
# 2022-08-18_istdaten.csv
# Zipped_data\2022-08-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166236
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-18_istdaten.csv.
# 2022-08-19_istdaten.csv
# Zipped_data\2022-08-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166486
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-19_istdaten.csv.
# 2022-08-20_istdaten.csv
# Zipped_data\2022-08-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  138910
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-20_istdaten.csv.
# 2022-08-21_istdaten.csv
# Zipped_data\2022-08-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  97120
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2022-08-21_istdaten.csv.
# 2022-08-22_istdaten.csv
# Zipped_data\2022-08-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  166119
# Number of NaN values in LINIEN_TEXT column:  0
# ...
# Number of NaN values in HALTESTELLEN_NAME column:  91137
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-08-27_istdaten.csv.
# 2021-08-28_istdaten.csv
# Zipped_data\2021-08-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  75911
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2021-08-28_istdaten.csv.
# 2021-08-29_istdaten.csv
# Zipped_data\2021-08-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  55537
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-08-29_istdaten.csv.
# 2021-08-30_istdaten.csv
# Zipped_data\2021-08-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  90175
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-08-30_istdaten.csv.
# 2021-08-31_istdaten.csv
# Zipped_data\2021-08-31_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  90563
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-08-31_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2021-08-01_istdaten.csv
# else:Zipped_data\2021-08-02_istdaten.csv
# else:Zipped_data\2021-08-03_istdaten.csv
# else:Zipped_data\2021-08-04_istdaten.csv
# else:Zipped_data\2021-08-05_istdaten.csv
# else:Zipped_data\2021-08-06_istdaten.csv
# else:Zipped_data\2021-08-07_istdaten.csv
# else:Zipped_data\2021-08-08_istdaten.csv
# else:Zipped_data\2021-08-09_istdaten.csv
# else:Zipped_data\2021-08-10_istdaten.csv
# else:Zipped_data\2021-08-11_istdaten.csv
# else:Zipped_data\2021-08-12_istdaten.csv
# else:Zipped_data\2021-08-13_istdaten.csv
# else:Zipped_data\2021-08-14_istdaten.csv
# else:Zipped_data\2021-08-15_istdaten.csv
# else:Zipped_data\2021-08-16_istdaten.csv
# else:Zipped_data\2021-08-17_istdaten.csv
# else:Zipped_data\2021-08-18_istdaten.csv
# else:Zipped_data\2021-08-19_istdaten.csv
# else:Zipped_data\2021-08-20_istdaten.csv
# else:Zipped_data\2021-08-21_istdaten.csv
# else:Zipped_data\2021-08-22_istdaten.csv
# else:Zipped_data\2021-08-23_istdaten.csv
# else:Zipped_data\2021-08-24_istdaten.csv
# else:Zipped_data\2021-08-25_istdaten.csv
# else:Zipped_data\2021-08-26_istdaten.csv
# else:Zipped_data\2021-08-27_istdaten.csv
# else:Zipped_data\2021-08-28_istdaten.csv
# else:Zipped_data\2021-08-29_istdaten.csv
# else:Zipped_data\2021-08-30_istdaten.csv
# else:Zipped_data\2021-08-31_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2021-07-01_istdaten.csv
# Zipped_data\2021-07-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89107
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-07-01_istdaten.csv.
# 2021-07-02_istdaten.csv
# Zipped_data\2021-07-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89565
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-07-02_istdaten.csv.
# 2021-07-03_istdaten.csv
# Zipped_data\2021-07-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  73792
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-03_istdaten.csv.
# 2021-07-04_istdaten.csv
# Zipped_data\2021-07-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  36999
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-04_istdaten.csv.
# 2021-07-05_istdaten.csv
# Zipped_data\2021-07-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  78562
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-05_istdaten.csv.
# 2021-07-06_istdaten.csv
# Zipped_data\2021-07-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87957
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-06_istdaten.csv.
# 2021-07-07_istdaten.csv
# Zipped_data\2021-07-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87983
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2021-07-07_istdaten.csv.
# 2021-07-08_istdaten.csv
# Zipped_data\2021-07-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88037
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-08_istdaten.csv.
# 2021-07-09_istdaten.csv
# Zipped_data\2021-07-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88855
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-09_istdaten.csv.
# 2021-07-10_istdaten.csv
# Zipped_data\2021-07-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  74960
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2021-07-10_istdaten.csv.
# 2021-07-11_istdaten.csv
# Zipped_data\2021-07-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  54626
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-11_istdaten.csv.
# 2021-07-12_istdaten.csv
# Zipped_data\2021-07-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  70339
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-12_istdaten.csv.
# 2021-07-13_istdaten.csv
# Zipped_data\2021-07-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87911
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-13_istdaten.csv.
# 2021-07-15_istdaten.csv
# Zipped_data\2021-07-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87764
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-15_istdaten.csv.
# 2021-07-16_istdaten.csv
# Zipped_data\2021-07-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88727
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2021-07-16_istdaten.csv.
# 2021-07-17_istdaten.csv
# Zipped_data\2021-07-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  75021
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-17_istdaten.csv.
# 2021-07-18_istdaten.csv
# Zipped_data\2021-07-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  54616
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-18_istdaten.csv.
# 2021-07-20_istdaten.csv
# Zipped_data\2021-07-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87784
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2021-07-20_istdaten.csv.
# 2021-07-21_istdaten.csv
# Zipped_data\2021-07-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87942
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-21_istdaten.csv.
# 2021-07-22_istdaten.csv
# Zipped_data\2021-07-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87962
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2021-07-22_istdaten.csv.
# 2021-07-26_istdaten.csv
# Zipped_data\2021-07-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87050
# Number of NaN values in LINIEN_TEXT column:  2
# processed 2021-07-26_istdaten.csv.
# 2021-07-27_istdaten.csv
# Zipped_data\2021-07-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87726
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2021-07-27_istdaten.csv.
# 2021-07-28_istdaten.csv
# Zipped_data\2021-07-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87556
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-28_istdaten.csv.
# 2021-07-29_istdaten.csv
# Zipped_data\2021-07-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  87536
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2021-07-29_istdaten.csv.
# 2021-07-30_istdaten.csv
# Zipped_data\2021-07-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  82476
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-30_istdaten.csv.
# 2021-07-31_istdaten.csv
# Zipped_data\2021-07-31_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  66934
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2021-07-31_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2021-07-01_istdaten.csv
# else:Zipped_data\2021-07-02_istdaten.csv
# else:Zipped_data\2021-07-03_istdaten.csv
# else:Zipped_data\2021-07-04_istdaten.csv
# else:Zipped_data\2021-07-05_istdaten.csv
# else:Zipped_data\2021-07-06_istdaten.csv
# else:Zipped_data\2021-07-07_istdaten.csv
# else:Zipped_data\2021-07-08_istdaten.csv
# else:Zipped_data\2021-07-09_istdaten.csv
# else:Zipped_data\2021-07-10_istdaten.csv
# else:Zipped_data\2021-07-11_istdaten.csv
# else:Zipped_data\2021-07-12_istdaten.csv
# else:Zipped_data\2021-07-13_istdaten.csv
# else:Zipped_data\2021-07-15_istdaten.csv
# else:Zipped_data\2021-07-16_istdaten.csv
# else:Zipped_data\2021-07-17_istdaten.csv
# else:Zipped_data\2021-07-18_istdaten.csv
# else:Zipped_data\2021-07-20_istdaten.csv
# else:Zipped_data\2021-07-21_istdaten.csv
# else:Zipped_data\2021-07-22_istdaten.csv
# else:Zipped_data\2021-07-26_istdaten.csv
# else:Zipped_data\2021-07-27_istdaten.csv
# else:Zipped_data\2021-07-28_istdaten.csv
# else:Zipped_data\2021-07-29_istdaten.csv
# else:Zipped_data\2021-07-30_istdaten.csv
# else:Zipped_data\2021-07-31_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data
# Processing data...
# 2021-06-01_istdaten.csv
# Zipped_data\2021-06-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  77038
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-01_istdaten.csv.
# 2021-06-02_istdaten.csv
# Zipped_data\2021-06-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  77052
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-02_istdaten.csv.
# 2021-06-03_istdaten.csv
# Zipped_data\2021-06-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  76911
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-03_istdaten.csv.
# 2021-06-04_istdaten.csv
# Zipped_data\2021-06-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  77353
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-04_istdaten.csv.
# 2021-06-05_istdaten.csv
# Zipped_data\2021-06-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  64118
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-05_istdaten.csv.
# 2021-06-06_istdaten.csv
# Zipped_data\2021-06-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  36632
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-06_istdaten.csv.
# 2021-06-07_istdaten.csv
# Zipped_data\2021-06-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  65341
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-07_istdaten.csv.
# 2021-06-08_istdaten.csv
# Zipped_data\2021-06-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  79649
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-08_istdaten.csv.
# 2021-06-09_istdaten.csv
# Zipped_data\2021-06-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88777
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-09_istdaten.csv.
# 2021-06-10_istdaten.csv
# Zipped_data\2021-06-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88858
# Number of NaN values in LINIEN_TEXT column:  66
# processed 2021-06-10_istdaten.csv.
# 2021-06-11_istdaten.csv
# Zipped_data\2021-06-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89409
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-11_istdaten.csv.
# 2021-06-12_istdaten.csv
# Zipped_data\2021-06-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  74572
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-12_istdaten.csv.
# 2021-06-13_istdaten.csv
# Zipped_data\2021-06-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  54757
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-13_istdaten.csv.
# 2021-06-14_istdaten.csv
# Zipped_data\2021-06-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88872
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-14_istdaten.csv.
# 2021-06-15_istdaten.csv
# Zipped_data\2021-06-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88620
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-15_istdaten.csv.
# 2021-06-16_istdaten.csv
# Zipped_data\2021-06-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88882
# Number of NaN values in LINIEN_TEXT column:  66
# processed 2021-06-16_istdaten.csv.
# 2021-06-17_istdaten.csv
# Zipped_data\2021-06-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89008
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-17_istdaten.csv.
# 2021-06-18_istdaten.csv
# Zipped_data\2021-06-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89476
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-18_istdaten.csv.
# 2021-06-19_istdaten.csv
# Zipped_data\2021-06-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  74606
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-19_istdaten.csv.
# 2021-06-20_istdaten.csv
# Zipped_data\2021-06-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  54507
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-20_istdaten.csv.
# 2021-06-21_istdaten.csv
# Zipped_data\2021-06-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89070
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-21_istdaten.csv.
# 2021-06-22_istdaten.csv
# Zipped_data\2021-06-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89089
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-22_istdaten.csv.
# 2021-06-23_istdaten.csv
# Zipped_data\2021-06-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89014
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-23_istdaten.csv.
# 2021-06-24_istdaten.csv
# Zipped_data\2021-06-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89035
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-24_istdaten.csv.
# 2021-06-25_istdaten.csv
# Zipped_data\2021-06-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89558
# Number of NaN values in LINIEN_TEXT column:  66
# processed 2021-06-25_istdaten.csv.
# 2021-06-26_istdaten.csv
# Zipped_data\2021-06-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  74566
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-26_istdaten.csv.
# 2021-06-27_istdaten.csv
# Zipped_data\2021-06-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  54507
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-27_istdaten.csv.
# 2021-06-28_istdaten.csv
# Zipped_data\2021-06-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89066
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-28_istdaten.csv.
# 2021-06-29_istdaten.csv
# Zipped_data\2021-06-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  88869
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-29_istdaten.csv.
# 2021-06-30_istdaten.csv
# Zipped_data\2021-06-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  89012
# Number of NaN values in LINIEN_TEXT column:  64
# processed 2021-06-30_istdaten.csv.
# Directory not found: Zipped_data\__MACOSX
# else:Zipped_data\2021-06-01_istdaten.csv
# else:Zipped_data\2021-06-02_istdaten.csv
# else:Zipped_data\2021-06-03_istdaten.csv
# else:Zipped_data\2021-06-04_istdaten.csv
# else:Zipped_data\2021-06-05_istdaten.csv
# else:Zipped_data\2021-06-06_istdaten.csv
# else:Zipped_data\2021-06-07_istdaten.csv
# else:Zipped_data\2021-06-08_istdaten.csv
# else:Zipped_data\2021-06-09_istdaten.csv
# else:Zipped_data\2021-06-10_istdaten.csv
# else:Zipped_data\2021-06-11_istdaten.csv
# else:Zipped_data\2021-06-12_istdaten.csv
# else:Zipped_data\2021-06-13_istdaten.csv
# else:Zipped_data\2021-06-14_istdaten.csv
# else:Zipped_data\2021-06-15_istdaten.csv
# else:Zipped_data\2021-06-16_istdaten.csv
# else:Zipped_data\2021-06-17_istdaten.csv
# else:Zipped_data\2021-06-18_istdaten.csv
# else:Zipped_data\2021-06-19_istdaten.csv
# else:Zipped_data\2021-06-20_istdaten.csv
# else:Zipped_data\2021-06-21_istdaten.csv
# else:Zipped_data\2021-06-22_istdaten.csv
# else:Zipped_data\2021-06-23_istdaten.csv
# else:Zipped_data\2021-06-24_istdaten.csv
# else:Zipped_data\2021-06-25_istdaten.csv
# else:Zipped_data\2021-06-26_istdaten.csv
# else:Zipped_data\2021-06-27_istdaten.csv
# else:Zipped_data\2021-06-28_istdaten.csv
# else:Zipped_data\2021-06-29_istdaten.csv
# else:Zipped_data\2021-06-30_istdaten.csv
# len(os.listdir(folder_name)) == 0Zipped_data

# %%
# für fehlerhafte Dateien wurde ein eigener Prozess erstellt
scraper_list = ['2023-04'] # '2022-12', 
data = pd.DataFrame() # pd.read_csv('combined_data.csv', delimiter=';')
for item in scraper_list:
    url = f'https://opentransportdata.swiss/wp-content/uploads/ist-daten-archive/ist-daten-{item}.zip'
    data = process_special_data(url, data, item)
    data.to_csv(f'Daten/v3/combined_data_{item}.csv', index=False)
# Out:
# Processing data...
# 2023-04-01_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-01_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  134297
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-01_istdaten.csv.
# 2023-04-02_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-02_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  95524
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-02_istdaten.csv.
# 2023-04-03_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-03_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159521
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-03_istdaten.csv.
# 2023-04-04_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-04_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160437
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-04_istdaten.csv.
# 2023-04-05_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-05_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160270
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-05_istdaten.csv.
# 2023-04-06_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-06_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161426
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-06_istdaten.csv.
# 2023-04-07_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-07_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  95072
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-07_istdaten.csv.
# 2023-04-08_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-08_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  133183
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-08_istdaten.csv.
# 2023-04-09_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-09_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  95053
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-09_istdaten.csv.
# 2023-04-10_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-10_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  96753
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-10_istdaten.csv.
# 2023-04-11_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-11_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159541
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-11_istdaten.csv.
# 2023-04-12_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-12_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  158917
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-12_istdaten.csv.
# 2023-04-13_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-13_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159681
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-13_istdaten.csv.
# 2023-04-14_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-14_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  157401
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-14_istdaten.csv.
# 2023-04-15_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-15_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  132105
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-15_istdaten.csv.
# 2023-04-16_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-16_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  90824
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-16_istdaten.csv.
# 2023-04-17_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-17_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  156780
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2023-04-17_istdaten.csv.
# 2023-04-18_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-18_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160019
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-18_istdaten.csv.
# 2023-04-19_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-19_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160075
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2023-04-19_istdaten.csv.
# 2023-04-20_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-20_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160442
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-20_istdaten.csv.
# 2023-04-21_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-21_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161184
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-21_istdaten.csv.
# 2023-04-22_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-22_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  132598
# Number of NaN values in LINIEN_TEXT column:  1
# processed 2023-04-22_istdaten.csv.
# 2023-04-23_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-23_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  93952
# Number of NaN values in LINIEN_TEXT column:  0
# processed 2023-04-23_istdaten.csv.
# 2023-04-24_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-24_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  155175
# Number of NaN values in LINIEN_TEXT column:  28
# processed 2023-04-24_istdaten.csv.
# 2023-04-25_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-25_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160548
# Number of NaN values in LINIEN_TEXT column:  31
# processed 2023-04-25_istdaten.csv.
# 2023-04-26_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-26_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  159791
# Number of NaN values in LINIEN_TEXT column:  46
# processed 2023-04-26_istdaten.csv.
# 2023-04-27_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-27_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  160759
# Number of NaN values in LINIEN_TEXT column:  48
# processed 2023-04-27_istdaten.csv.
# 2023-04-28_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-28_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  161984
# Number of NaN values in LINIEN_TEXT column:  47
# processed 2023-04-28_istdaten.csv.
# 2023-04-29_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-29_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  132934
# Number of NaN values in LINIEN_TEXT column:  36
# processed 2023-04-29_istdaten.csv.
# 2023-04-30_istdaten.csv
# Zipped_data/ist-daten-2023-04\2023-04-30_istdaten.csv
# Number of NaN values in HALTESTELLEN_NAME column:  94361
# Number of NaN values in LINIEN_TEXT column:  36
# processed 2023-04-30_istdaten.csv.

# %% [markdown]
# Finaler Datensatz mit Informationen wird zusammengestellt und gespeichert für das Feature Engineering.

# %%
# Delete the folder and the zip file
for file_name in os.listdir('Zipped_data'):
    file_path = os.path.join('Zipped_data', file_name)
    if os.path.isdir(file_path):
        shutil.rmtree(file_path)
        print(f'Removed directory: {file_path}')
    else:
        os.remove(file_path)
        print(f'Removed file: {file_path}')
# Out:
# Removed directory: Zipped_data\ist-daten-2022-12
# Removed directory: Zipped_data\ist-daten-2023-04

# %%
# csv aus ordner zusammenfügen
import pandas as pd
import os

# Define the folder to extract the zip file contents
folder_name = 'Daten/v3'
df_list = []
for file_name in os.listdir(folder_name):
    if file_name.endswith('.csv'):
        file_path = os.path.join(folder_name, file_name)
        df = pd.read_csv(file_path, delimiter = ';', on_bad_lines='skip', dayfirst=True, low_memory=False)
        df_list.append(df)
        print(f"processed {file_name}.")
df_combined = pd.concat(df_list, axis=0)
df_combined.drop_duplicates(inplace=True)
df_combined.to_csv('./Daten/two_years/combined_data.csv',sep=";", index=False)
# Out:
# processed combined_data_2021-06.csv.
# processed combined_data_2021-07.csv.
# processed combined_data_2021-08.csv.
# processed combined_data_2021-09.csv.
# processed combined_data_2021-10.csv.
# processed combined_data_2021-11.csv.
# processed combined_data_2021-12.csv.
# processed combined_data_2022-01.csv.
# processed combined_data_2022-02.csv.
# processed combined_data_2022-03.csv.
# processed combined_data_2022-04.csv.
# processed combined_data_2022-05.csv.
# processed combined_data_2022-06.csv.
# processed combined_data_2022-07.csv.
# processed combined_data_2022-08.csv.
# processed combined_data_2022-09.csv.
# processed combined_data_2022-10.csv.
# processed combined_data_2022-11.csv.
# processed combined_data_2022-12.csv.
# processed combined_data_2023-01.csv.
# processed combined_data_2023-02.csv.
# processed combined_data_2023-03.csv.
# processed combined_data_2023-04.csv.
# processed combined_data_2023-05.csv.

# %%
# Split df_combined in two
df_combined_1 = df_combined.iloc[:int(len(df_combined)/2)]
df_combined_2 = df_combined.iloc[int(len(df_combined)/2):]
# Save to csv
df_combined_1.to_csv('./Daten/two_years/combined_data_1.csv',sep=";", index=False)
df_combined_2.to_csv('./Daten/two_years/combined_data_2.csv',sep=";", index=False)
